# %%
import pandas as pd

# %%
# import pipeline
from utils import *

# %%
# example test dictionary
names_dict = {
    "Petr Nesladek": "petr.nesladek@example.com",
    "Petr Klen": "petr.klen@example.com",
    "Terry Stone": "terry.stone@example.com",
    "Radim Moravec": "radim.moravec@example.com",
    "Lukas Kawulok": "lukas.kawulok@example.com",
    "Rene Gruszkowski": "rene.gruszkowski@example.com",
    "Stephen Pack": "stephen.pack@example.com",
    "Gloria Kee": "gloria.kee@example.com",
    "Jiri Sverepa": "jiri.sverepa@example.com",
    "Chintan Modha": "chintan.modha@example.com",
    "Petr Lofferman": "petr.lofferman@example.com",
    "Zain Master": "zain.master@example.com"
}

# %%
# read in test transcript
transcript_json = pd.read_json('Resources/vertopal.com_Discuss Collaborative Testing prior to release.json', orient='index')
transcript = str(transcript_json[0])
transcript[:1000]
# Out:
# "\ufeffTranscript\\nApril 29, 2025, 2:02PM\\n\\nZain Master started transcription\\n\\nZain Master   0:03\\nEverybody, the purpose of this meeting is to talk about and understand and formulate plans on how to make sure that we can increase the confidence of our.\\nReleases going out to customers, right? As we understand most of our products are impacted by a level of customizations that involve very specific customer setups and implementations.\\nSo while the product is able to perform a level of testing, there needs to be that next level of testing that is performed in specific to that customer's implementation and that specific environment. Many times as we've seen, we've gotten a release out there only to have it.\\nImpacted either by product score functionality that needs to be compatible with a implementation, or the implementation side of the House.\\nThat's incompatible with product and then that gets us into this wonderful spiral of trying to continually address.\\nThe issue and release after r"

# %%
# run all with main function
main(transcript, names_dict)
# Out:
# c:\Users\Nik\Desktop\Meeting-Bot\utils.py:221: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   summary = chain.run(input_documents=batch)
# Generated email for Lukas Kawulok (lukas.kawulok@example.com)
# Generated email for Petr Klen (petr.klen@example.com)
# Generated email for Radim Moravac (radim.moravec@example.com)
# Generated email for Stephen Pack (stephen.pack@example.com)
# Generated email for Terry Stone (terry.stone@example.com)
# Generated email for Zain Master (zain.master@example.com)
#
# --- Generated Emails ---
# To: lukas.kawulok@example.com
#
# From: znpmeetingassistant@gmail.com
#
# Subject: Summary and Action Items from April 29, 2025 Meeting
#
# Dear Lukas Kawulok,
#
# Meeting Summary:
#
# The transcript from April 29, 2025, captures a comprehensive discussion led by Zain Master, aimed at enhancing customer confidence in product releases through improved testing and collaboration strategies. The meeting focuses on addressing the challenges posed by customer-specific customizations and the subsequent issues that arise post-release.
#
# Key Strategies and Discussions:
#
# 1. Enhanced Collaboration:
# - Proposed strategy for better integration between the solution center and the core product team to resolve compatibility issues before product releases.
#
# 2. Phased Releases:
# - Discussed the idea of releasing updates in waves to manage risks.
#
# 3. Technical and Logistical Challenges:
# - Challenges of implementing a tiered release system were elaborated on.
#
# 4. Resource Allocation for Testing:
# - Suggested a more formalized process for reserving QA resources ahead of release dates.
#
# 5. Structured Communication Strategy:
# - Highlighted the necessity for a coordinated communication strategy to keep all teams aligned.
#
# Additional Focus Areas:
# - Inclusion of Solution Center in Demo Meetings
# - Documentation and Accessibility
# - Efficient Communication Model
# - API and Integration Testing
# - Security and Access Management
#
# Calls to Action:
#
# - Generate and store output for integrations prior to every release to compare.
# - Integrate solution center resources into demo meetings to keep track of customization work.
# - Include API performance testing in the testing scope.
# - Plan for API performance testing in the roadmap.
# - Improve management of accesses to connectors and two-factor authentication.
# - Schedule another meeting to ensure all action items are addressed.
#
# Specific Call to Action for Lukas Kawulok:
#
# There were no calls to action directed towards you in the meeting. However, please stay informed about the ongoing discussions and upcoming meetings for further updates.
#
# Thank you for your attention to this matter. If you have any questions or need clarification, feel free to reach out.
#
# Best regards,
#
# ZNP Meeting Assistant
# To: petr.klen@example.com
#
# From: znpmeetingassistant@gmail.com
#
# Subject: Action Items and Meeting Summary Review
#
# Dear Petr,
#
# I hope this message finds you well. The purpose of this email is to provide you with a summary of the recent meeting held on April 29, 2025, and outline the action items assigned to each team member.
#
# Meeting Summary:
#
# The transcript from April 29, 2025, showcases a detailed discussion led by Zain Master to enhance customer confidence in product releases through improved testing and collaboration strategies. The key points discussed include enhanced collaboration between teams, phased releases, technical challenges, resource allocation for testing, structured communication strategies, and additional focus areas such as API performance testing and security management.
#
# Calls to Action:
#
# - Generate and store output for integrations prior to every release to compare
# - Integrate solution center resources into demo meetings to keep track of customization work
# - Include API performance testing in the testing scope
# - Plan for API performance testing in the roadmap
# - Improve management of accesses to connectors and two-factor authentication
# - Schedule another meeting to ensure all action items are addressed
#
# Specific Call to Action for Petr Klen:
#
# Petr, your specific action item is to request bookings of resources for August by the end of July and check the availability in mid-May. This will help formalize the process for reserving QA resources ahead of release dates.
#
# Thank you for your dedication to this project. Should you require any clarification or assistance, please feel free to reach out.
#
# Best regards,
#
# ZNP Meeting Assistant
#
# *! Warning! Assignments of tasks and Summaries generated by this Bot may be inaccurate. Please be sure to follow up with Meeting Organizer / Team Lead*
# To: radim.moravec@example.com
#
# From: znpmeetingassistant@gmail.com
#
# Subject: Summary of April 29, 2025 Meeting and Action Items
#
# Meeting Summary:
#
# The meeting held on April 29, 2025, led by Zain Master, focused on enhancing customer confidence in product releases through improved testing and collaboration strategies. Key strategies and discussions included enhanced collaboration between teams, phased releases, technical challenges, resource allocation for testing, and structured communication strategies.
#
# Additional focus areas were on the involvement of the Solution Center in demo meetings, documentation, efficient communication models, API and integration testing, and security and access management.
#
# Conclusion and Future Actions:
#
# The consensus was on integrating the Solution Center into the development process, improving communication, and ensuring quality. Plans for further discussions were set to enhance software reliability and customer satisfaction.
#
# Calls to Action:
#
# - Generate and store output for integrations prior to every release to compare.
# - Integrate Solution Center resources into demo meetings to track customization work.
# - Include API performance testing in the testing scope.
# - Plan for API performance testing in the roadmap.
# - Improve management of accesses to connectors and two-factor authentication.
#
# Specific Call to Action for Radim Moravac:
#
# There were no calls to action directed towards you in this meeting. Should you have any questions or require further information, feel free to reach out.
#
# Thank you for your participation in the meeting. Your involvement is valuable in our efforts to enhance our testing and collaboration strategies.
#
# Best regards,
# ZNP Meeting Assistant
#
# ! Warning ! Assignments of tasks and Summaries generated by this Bot may be inaccurate. Please be sure to follow up with Meeting Organizer / Team Lead
# To: stephen.pack@example.com
#
# From: znpmeetingassistant@gmail.com
#
# Subject: Summary and Action Items from April 29, 2025, Meeting
#
# Dear Stephen Pack,
#
# I hope this email finds you well. Please see below the summary of our recent meeting held on April 29, 2025, along with the assigned action items for all members:
#
# Meeting Summary:
#
# The meeting, led by Zain Master, focused on enhancing customer confidence in product releases through improved testing and collaboration strategies. Key strategies and discussions included the enhancement of collaboration between the solution center and the core product team, phased releases, technical challenges, resource allocation for testing, and a structured communication strategy. Additional focus areas highlighted were the inclusion of the solution center in demo meetings, documentation and accessibility, efficient communication models, API and integration testing, and security and access management.
#
# The conclusion emphasized the need for better integration of the solution center in the development process, structured communication of changes, and adjustments in the pace to ensure quality and understanding for improved software reliability and enhanced customer satisfaction.
#
# Calls to Action:
#
# - Generate and store output for integrations prior to every release to compare.
# - Integrate solution center resources into demo meetings to keep track of customization work.
# - Include API performance testing in the testing scope.
# - Plan for API performance testing in the roadmap.
# - Improve management of accesses to connectors and two-factor authentication.
# - Schedule another meeting to ensure all action items are addressed.
#
# Specific Call to Action for Stephen Pack:
#
# Stephen, your specific action item is to formalize the process with Peter to define how to communicate about needing resources and capture this process effectively.
#
# Thank you for your attention to these action items. Should you have any questions or need further clarification, please feel free to reach out.
#
# Best regards,
#
# ZNP Meeting Assistant
# To: terry.stone@example.com
#
# From: znpmeetingassistant@gmail.com
#
# Subject: Summary of April 29, 2025 Meeting Discussion and Action Items
#
# Meeting Summary:
#
# The transcript from April 29, 2025, captures a comprehensive discussion led by Zain Master to enhance customer confidence in product releases through improved testing and collaboration strategies. Key strategies and discussions include enhanced collaboration between the solution center and core product team, phased releases, technical challenges, resource allocation for testing, and structured communication strategy. Additional focus areas involve the inclusion of the solution center in demo meetings, documentation, efficient communication model, API and integration testing, and security and access management.
#
# Calls to Action:
#
# - Generate and store output for integrations prior to every release to compare.
# - Integrate solution center resources into demo meetings to keep track of customization work.
# - Include API performance testing in the testing scope.
# - Plan for API performance testing in the roadmap.
# - Improve management of accesses to connectors and two-factor authentication.
# - Schedule another meeting to ensure all action items are addressed.
#
# Specific Call to Action for Terry Stone:
#
# Terry, your specific action item is to work on managing three gateways for waves of releases and ensure DNS routes everyone in the right wave to the right gateway.
#
# Thank you for your attention and dedication. Should you need any further assistance or clarification, please feel free to reach out.
#
# Best regards,
# ZNP Meeting Assistant
# To: zain.master@example.com
#
# From: znpmeetingassistant@gmail.com
#
# Subject: Follow-Up on April 29, 2025 Meeting Summary
#
# This email summarizes the discussion led by you during the meeting on April 29, 2025, focusing on enhancing customer confidence in product releases through improved testing and collaboration strategies.
#
# Meeting Summary:
#
# The key strategies and discussions from the meeting include enhanced collaboration between the solution center and the core product team, phased releases, technical and logistical challenges, resource allocation for testing, and a structured communication strategy. Additional focus areas highlighted were the inclusion of the Solution Center in demo meetings, documentation and accessibility, efficient communication models, API and integration testing, and security and access management.
#
# Conclusion and Future Actions:
#
# The consensus reached was the integration of the solution center in the development process, structured communication of changes, and adjusting the pace to enhance software reliability and customer satisfaction. Plans for further discussions and meetings were set to refine processes, aiming for strategic planning and collaboration.
#
# Calls to Action:
#
# - Work with Stephen to plan and put in place better communication regarding delayed releases.
#
# Thank you for leading the discussion and your contributions to the meeting. Please let me know if you have any questions or need further clarification.
#
# Best regards,
# ZNP Meeting Assistant
#
# Note: Assignments of tasks and summaries presented by this Bot may be inaccurate. Ensure to follow up with the meeting organizer / team lead for confirmation.
# Email sent successfully to lukas.kawulok@example.com
# Email sent successfully to petr.klen@example.com
# Email sent successfully to radim.moravec@example.com
# Email sent successfully to stephen.pack@example.com
# Email sent successfully to terry.stone@example.com
# Email sent successfully to zain.master@example.com
